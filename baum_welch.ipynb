# %%
import numpy as np

class Baum_welch():
    def __init__(self, pi, P, E, seq):
        self.pi = pi
        self.P = P
        self.E = E
        self.seq = seq
        self.update_dependent_variables()
    
    def update_dependent_variables(self):
        self.alphas = self.forward()
        self.betas = self.backward()
        self.normalizing = self.normalizing_factor()
        self.gammas = self.gamma()
        self.xi_all = self.xi()

    def forward(self):
        Alpha = np.zeros((self.P.shape[0], len(self.seq)))
        Alpha[:,0] = (np.diagflat(self.E[:, self.seq[0]]) @ self.pi).flatten()
        Pt = np.transpose(self.P)
        for index, observation in enumerate(self.seq[1:], 1):
            Alpha[:,index] = np.diagflat(self.E[:, observation]) @ Pt @ Alpha[:,index-1]
        return Alpha

    def backward(self):
        seq_size = len(self.seq)
        Beta = np.ones((self.P.shape[0], seq_size))
        rev = self.seq[::-1][:-1]
        for index, observation in enumerate(rev, 1):
            Beta[:,seq_size-index-1] = self.P @ np.diagflat(self.E[:, observation]) @ Beta[:,seq_size-index]
        return Beta

    def normalizing_factor(self):
        return self.alphas[:,-1].sum()

    def gamma(self):
        return (self.alphas * self.betas) / self.normalizing

    def xi(self):
        xi_all = []
        for index in range(len(self.seq[:-1])):
            xi_1 = np.zeros(self.P.shape)
            for i in range(self.P.shape[0]):
                for j in range(self.P.shape[0]):
                    c = (self.alphas[i,index] * self.P[i,j] * 
                         self.E[j,self.seq[index+1]] * self.betas[j,index+1]) / self.normalizing
                    xi_1[i][j] = c
            xi_all.append(xi_1)
        return xi_all

    def sum_seq_gammas(self, state):
        unique_observation = {}
        for num in self.seq:
            if num not in unique_observation:
                unique_observation[num] = 0
        for idx, num in enumerate(self.seq):
            unique_observation[num] += self.gammas[state][idx]
        return unique_observation

    def calculate_emission(self):
        size = self.E.shape
        new_E = np.zeros(size)
        for i in range(size[0]):
            numerator_part = self.sum_seq_gammas(i)
            denominator = self.gammas[i].sum()
            if denominator != 0:  # prevent division by zero
                for j in range(size[1]):
                    new_E[i,j] = numerator_part[j] / denominator
        return new_E

    def update_sum(self, state):
        sum_xi = 0
        sum_gamma = 0
        for i in range(len(self.seq)-1):
            sum_xi += self.xi_all[i][state[0]][state[1]]
            sum_gamma += self.gammas[state[0]][i]
        return sum_xi, sum_gamma

    def fit_once(self):
        p_size = self.P.shape
        new_P = np.zeros(p_size)
        new_pi = np.zeros(self.pi.shape)
        
        for i in range(new_pi.shape[0]):
            for j in range(new_pi.shape[1]):
                new_pi[i, j] = self.gammas[i, 0]
        
        for i in range(p_size[0]):
            for j in range(p_size[0]):
                sum_xi, sum_gamma = self.update_sum((i, j))
                new_P[i, j] = sum_xi / sum_gamma if sum_gamma != 0 else 0
        
        new_E = self.calculate_emission()
        
        return new_P, new_pi, new_E

    def fit_all(self, max_iter=1000, tolerance=1e-6):
        old_P = np.copy(self.P)
        
        for i in range(max_iter):
            print(f"\nIteration {i}:")

            
            new_P, new_pi, new_E = self.fit_once()
            
            self.P = new_P.copy()
            self.pi = new_pi.copy()
            self.E = new_E.copy()
            self.update_dependent_variables()
            print("\n New P matrix:")
            print(self.P)
            print("\n New E matrix:")
            print(self.P)
            print("\n New pi matrix:")
            print(self.P)
            print('-' * 80)
            
            diff = np.max(np.abs(self.P - old_P))
            print(f"Maximum parameter difference: {diff}")
            
            if diff < tolerance:
                print(f"\nConverged after {i+1} iterations!")
                break
        
        return self.P, self.pi, self.E

# %%
pi = np.matrix([[0.8],
                [0.2]])
P= np.matrix([[0.1,0.9],
             [0.5,0.5]])
E = np.matrix([[0.1,0.7,0.2],
              [0.6,0.2,0.2]])
seq = [0,2,1,1,1,2,2,2]
baum = Baum_welch(pi, P ,E ,seq)
baum.fit_all(max_iter=100)
# Out:
# Iteration 0:
#
#  New P matrix:
# [[0.14460942 0.85539058]
#  [0.58437685 0.41562315]]
#
#  New E matrix:
# [[0.14460942 0.85539058]
#  [0.58437685 0.41562315]]
#
#  New pi matrix:
# [[0.14460942 0.85539058]
#  [0.58437685 0.41562315]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.08437684653819666
#
# Iteration 1:
#
#  New P matrix:
# [[0.13970413 0.86029587]
#  [0.5752851  0.4247149 ]]
#
#  New E matrix:
# [[0.13970413 0.86029587]
#  [0.5752851  0.4247149 ]]
#
#  New pi matrix:
# [[0.13970413 0.86029587]
#  [0.5752851  0.4247149 ]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.07528509901702801
#
# Iteration 2:
#
#  New P matrix:
# [[0.12722712 0.87277288]
#  [0.56470429 0.43529571]]
#
#  New E matrix:
# [[0.12722712 0.87277288]
#  [0.56470429 0.43529571]]
#
#  New pi matrix:
# [[0.12722712 0.87277288]
#  [0.56470429 0.43529571]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.06470429150552481
#
# Iteration 3:
#
#  New P matrix:
# [[0.10543312 0.89456688]
#  [0.54510787 0.45489213]]
#
#  New E matrix:
# [[0.10543312 0.89456688]
#  [0.54510787 0.45489213]]
#
#  New pi matrix:
# [[0.10543312 0.89456688]
#  [0.54510787 0.45489213]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.04510786600978933
#
# Iteration 4:
#
#  New P matrix:
# [[0.07745148 0.92254852]
#  [0.50767905 0.49232095]]
#
#  New E matrix:
# [[0.07745148 0.92254852]
#  [0.50767905 0.49232095]]
#
#  New pi matrix:
# [[0.07745148 0.92254852]
#  [0.50767905 0.49232095]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.022548523548315172
#
# Iteration 5:
#
#  New P matrix:
# [[0.05222877 0.94777123]
#  [0.45712898 0.54287102]]
#
#  New E matrix:
# [[0.05222877 0.94777123]
#  [0.45712898 0.54287102]]
#
#  New pi matrix:
# [[0.05222877 0.94777123]
#  [0.45712898 0.54287102]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.04777123121601863
#
# Iteration 6:
#
#  New P matrix:
# [[0.03331545 0.96668455]
#  [0.39963262 0.60036738]]
#
#  New E matrix:
# [[0.03331545 0.96668455]
#  [0.39963262 0.60036738]]
#
#  New pi matrix:
# [[0.03331545 0.96668455]
#  [0.39963262 0.60036738]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.10036737600937806
#
# Iteration 7:
#
#  New P matrix:
# [[0.02004668 0.97995332]
#  [0.33558036 0.66441964]]
#
#  New E matrix:
# [[0.02004668 0.97995332]
#  [0.33558036 0.66441964]]
#
#  New pi matrix:
# [[0.02004668 0.97995332]
#  [0.33558036 0.66441964]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.16441964238991025
#
# Iteration 8:
#
#  New P matrix:
# [[0.01115055 0.98884945]
#  [0.26625142 0.73374858]]
#
#  New E matrix:
# [[0.01115055 0.98884945]
#  [0.26625142 0.73374858]]
#
#  New pi matrix:
# [[0.01115055 0.98884945]
#  [0.26625142 0.73374858]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.2337485754082942
#
# Iteration 9:
#
#  New P matrix:
# [[0.0054611 0.9945389]
#  [0.1946408 0.8053592]]
#
#  New E matrix:
# [[0.0054611 0.9945389]
#  [0.1946408 0.8053592]]
#
#  New pi matrix:
# [[0.0054611 0.9945389]
#  [0.1946408 0.8053592]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.3053591993867536
#
# Iteration 10:
#
#  New P matrix:
# [[0.00212659 0.99787341]
#  [0.12536149 0.87463851]]
#
#  New E matrix:
# [[0.00212659 0.99787341]
#  [0.12536149 0.87463851]]
#
#  New pi matrix:
# [[0.00212659 0.99787341]
#  [0.12536149 0.87463851]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.3746385105580028
#
# Iteration 11:
#
#  New P matrix:
# [[5.35079898e-04 9.99464920e-01]
#  [6.47890766e-02 9.35210923e-01]]
#
#  New E matrix:
# [[5.35079898e-04 9.99464920e-01]
#  [6.47890766e-02 9.35210923e-01]]
#
#  New pi matrix:
# [[5.35079898e-04 9.99464920e-01]
#  [6.47890766e-02 9.35210923e-01]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.43521092342704115
#
# Iteration 12:
#
#  New P matrix:
# [[5.85467862e-05 9.99941453e-01]
#  [2.17276873e-02 9.78272313e-01]]
#
#  New E matrix:
# [[5.85467862e-05 9.99941453e-01]
#  [2.17276873e-02 9.78272313e-01]]
#
#  New pi matrix:
# [[5.85467862e-05 9.99941453e-01]
#  [2.17276873e-02 9.78272313e-01]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.47827231270994097
#
# Iteration 13:
#
#  New P matrix:
# [[1.56264842e-06 9.99998437e-01]
#  [2.92849195e-03 9.97071508e-01]]
#
#  New E matrix:
# [[1.56264842e-06 9.99998437e-01]
#  [2.92849195e-03 9.97071508e-01]]
#
#  New pi matrix:
# [[1.56264842e-06 9.99998437e-01]
#  [2.92849195e-03 9.97071508e-01]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.49707150805214717
#
# Iteration 14:
#
#  New P matrix:
# [[4.37192574e-09 9.99999996e-01]
#  [5.79417352e-05 9.99942058e-01]]
#
#  New E matrix:
# [[4.37192574e-09 9.99999996e-01]
#  [5.79417352e-05 9.99942058e-01]]
#
#  New pi matrix:
# [[4.37192574e-09 9.99999996e-01]
#  [5.79417352e-05 9.99942058e-01]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.49994205826481886
#
# Iteration 15:
#
#  New P matrix:
# [[1.87913815e-13 1.00000000e+00]
#  [2.30803056e-08 9.99999977e-01]]
#
#  New E matrix:
# [[1.87913815e-13 1.00000000e+00]
#  [2.30803056e-08 9.99999977e-01]]
#
#  New pi matrix:
# [[1.87913815e-13 1.00000000e+00]
#  [2.30803056e-08 9.99999977e-01]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.49999997691969444
#
# Iteration 16:
#
#  New P matrix:
# [[2.45709792e-21 1.00000000e+00]
#  [3.67860988e-15 1.00000000e+00]]
#
#  New E matrix:
# [[2.45709792e-21 1.00000000e+00]
#  [3.67860988e-15 1.00000000e+00]]
#
#  New pi matrix:
# [[2.45709792e-21 1.00000000e+00]
#  [3.67860988e-15 1.00000000e+00]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.49999999999999634
#
# Iteration 17:
#
#  New P matrix:
# [[3.89303460e-36 1.00000000e+00]
#  [9.37538046e-29 1.00000000e+00]]
#
#  New E matrix:
# [[3.89303460e-36 1.00000000e+00]
#  [9.37538046e-29 1.00000000e+00]]
#
#  New pi matrix:
# [[3.89303460e-36 1.00000000e+00]
#  [9.37538046e-29 1.00000000e+00]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 18:
#
#  New P matrix:
# [[1.19123432e-64 1.00000000e+00]
#  [6.10503009e-56 1.00000000e+00]]
#
#  New E matrix:
# [[1.19123432e-64 1.00000000e+00]
#  [6.10503009e-56 1.00000000e+00]]
#
#  New pi matrix:
# [[1.19123432e-64 1.00000000e+00]
#  [6.10503009e-56 1.00000000e+00]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 19:
#
#  New P matrix:
# [[1.79413178e-120 1.00000000e+000]
#  [2.59367271e-110 1.00000000e+000]]
#
#  New E matrix:
# [[1.79413178e-120 1.00000000e+000]
#  [2.59367271e-110 1.00000000e+000]]
#
#  New pi matrix:
# [[1.79413178e-120 1.00000000e+000]
#  [2.59367271e-110 1.00000000e+000]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 20:
#
#  New P matrix:
# [[8.66081162e-231 1.00000000e+000]
#  [4.68812928e-219 1.00000000e+000]]
#
#  New E matrix:
# [[8.66081162e-231 1.00000000e+000]
#  [4.68812928e-219 1.00000000e+000]]
#
#  New pi matrix:
# [[8.66081162e-231 1.00000000e+000]
#  [4.68812928e-219 1.00000000e+000]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 21:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 22:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 23:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 24:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 25:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 26:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 27:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 28:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 29:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 30:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 31:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 32:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 33:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 34:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 35:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 36:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 37:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 38:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 39:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 40:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 41:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 42:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 43:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 44:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 45:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 46:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 47:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 48:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 49:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 50:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 51:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 52:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 53:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 54:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 55:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 56:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 57:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 58:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 59:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 60:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 61:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 62:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 63:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 64:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 65:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 66:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 67:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 68:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 69:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 70:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 71:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 72:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 73:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 74:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 75:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 76:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 77:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 78:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 79:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 80:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 81:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 82:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 83:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 84:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 85:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 86:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 87:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 88:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 89:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 90:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 91:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 92:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 93:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 94:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 95:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 96:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 97:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 98:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
#
# Iteration 99:
#
#  New P matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New E matrix:
# [[0. 1.]
#  [0. 1.]]
#
#  New pi matrix:
# [[0. 1.]
#  [0. 1.]]
# --------------------------------------------------------------------------------
# Maximum parameter difference: 0.5
# (array([[0., 1.],
#         [0., 1.]]),
#  array([[1.],
#         [0.]]),
#  array([[1.        , 0.        , 0.        ],
#         [0.        , 0.42857143, 0.57142857]]))

# %%
new_pi = np.array([[0.43885602],
                   [0.56114398]])

# New P
new_P = np.array([[0.14460942, 0.85539058],
                  [0.58437685, 0.41562315]])

# New E
new_E = np.array([[0.13501309, 0.48074687, 0.38424003],
                  [0.11814727, 0.30262925, 0.57922348]])
baum2 = Baum_welch(new_pi, new_P ,new_E ,seq)
baum2.fit_all(max_iter=100)
# Out:
# [[0.14460942 0.85539058]
#  [0.58437685 0.41562315]]
#
#  Iteration:  0
#  ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# New pi:
#  [[0.53013787]
#  [0.46986213]]
#  --------------------------------------------------------------------------------
# New P:
#  [[0.13970414 0.86029586]
#  [0.5752851  0.4247149 ]]
#  --------------------------------------------------------------------------------
# New E:
#  [[0.16192498 0.44718552 0.3908895 ]
#  [0.09942009 0.32499323 0.57558667]]
#  --------------------------------------------------------------------------------
#
#  Difference =  0.009091748978305003
# [[0.13970414 0.86029586]
#  [0.5752851  0.4247149 ]]
#
#  Iteration:  1
#  ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# New pi:
#  [[0.53013787]
#  [0.46986213]]
#  --------------------------------------------------------------------------------
# New P:
#  [[0.13970414 0.86029586]
#  [0.5752851  0.4247149 ]]
#  --------------------------------------------------------------------------------
# New E:
#  [[0.16192498 0.44718552 0.3908895 ]
#  [0.09942009 0.32499323 0.57558667]]
#  --------------------------------------------------------------------------------
#
#  Difference =  0.0
# (array([[0.13970414, 0.86029586],
#         [0.5752851 , 0.4247149 ]]),
#  array([[0.53013787],
#         [0.46986213]]),
#  array([[0.16192498, 0.44718552, 0.3908895 ],
#         [0.09942009, 0.32499323, 0.57558667]]))
